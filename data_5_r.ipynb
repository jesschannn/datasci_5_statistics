# %% [markdown]
# <a href="https://colab.research.google.com/github/jesschannn/datasci_5_statistics/blob/main/data_5_r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chi Square

# %% [markdown]
# **Null Hypothesis**: There is no association between the brand name of a medication and indications for anti-psychotics (flagged as yes or no).
#
# **Alternative Hypothesis**: There is an association between the brand name of a medication and indications for anti-psychotics (flagged as yes or no).
#
# **Interpretation**: The purpose of a chi-squared test is to measure how a model compared to observed data and whether the difference between expected and observed data is due to chance or if there's a relationship. Because the chi-square value derived from my calculations is significantly greater than the chi-square value that is expected, the null hypothesis has to be rejected.

# %%
df1 <-read.csv('medicare_prescriber.csv')
df1
# Out:
#        Prscrbr_Geo_Lvl Prscrbr_Geo_Cd Prscrbr_Geo_Desc
# 1      National                       National
# 2      National                       National
# 3      National                       National
# 4      National                       National
# 5      National                       National
# 6      National                       National
# 7      National                       National
# 8      National                       National
# 9      National                       National
# 10     National                       National
# 11     National                       National
# 12     National                       National
# 13     National                       National
# 14     National                       National
# 15     National                       National
# 16     National                       National
# 17     National                       National
# 18     National                       National
# 19     National                       National
# ...

# %%
contingency = table(df1$Brnd_Name, df1$Antpsyct_Drug_Flag)
contingency
# Out:
#
#                                    N   Y
#   1st Tier Unifine Pentips        23   0
#   1st Tier Unifine Pentips Plus   39   0
#   Abacavir                        53   0
#   Abacavir-Lamivudine             51   0
#   Abacavir-Lamivudine-Zidovudine   5   0
#   Abelcet                         10   0
#   Abilify                          1  52
#   Abilify Maintena                 3  54
#   Abilify Mycite                   1   1
#   Abiraterone Acetate             56   0
#   Abraxane                        14   0
#   Absorica                         4   0
#   Absorica Ld                      1   0
#   Acamprosate Calcium             53   0
#   Acanya                           2   0
#   Acarbose                        57   0
#   Accolate                        22   0
#   Accupril                        38   0
#   Accuretic                       13   0
#   Accutane                         3   0
#   Acebutolol Hcl                  55   0
#   Acetamin-Caff-Dihydrocodeine    17   0
# ...

# %%
chisq.test(contingency)
# Out:
# Warning message in chisq.test(contingency):
# “Chi-squared approximation may be incorrect”
# 	Pearson's Chi-squared test
#
# data:  contingency
# X-squared = 108966, df = 3407, p-value < 2.2e-16

# %% [markdown]
# # T-Test

# %% [markdown]
# **Null Hypothesis**: The average radius for malignant breast cancer cell nuclei is not different from benign breast cancer cell nuclei.
#
# **Alternative Hypothesis**: The average radius for malignant breast cancer cell nuclei is different from benign breast cancer cell nuclei.
#
# **Interpretation**: The purpose of the t-test is to determine if there is a significant difference between the means of two groups and how they are related. Since the p-value is much smaller than 0.05, the null hypothesis is rejected.

# %%
df2 = read.csv('breast_cancer.csv')
df2
# Out:
#     id       diagnosis radius_mean texture_mean perimeter_mean area_mean
# 1     842302 M         17.990      10.38        122.80         1001.0
# 2     842517 M         20.570      17.77        132.90         1326.0
# 3   84300903 M         19.690      21.25        130.00         1203.0
# 4   84348301 M         11.420      20.38         77.58          386.1
# 5   84358402 M         20.290      14.34        135.10         1297.0
# 6     843786 M         12.450      15.70         82.57          477.1
# 7     844359 M         18.250      19.98        119.60         1040.0
# 8   84458202 M         13.710      20.83         90.20          577.9
# 9     844981 M         13.000      21.82         87.50          519.8
# 10  84501001 M         12.460      24.04         83.97          475.9
# 11    845636 M         16.020      23.24        102.70          797.8
# 12  84610002 M         15.780      17.89        103.60          781.0
# ...

# %%
malignant_data <- subset(df2, diagnosis == 'M')$radius_mean
malignant_data
# Out:
#   [1] 17.99 20.57 19.69 11.42 20.29 12.45 18.25 13.71 13.00 12.46 16.02 15.78
#  [13] 19.17 15.85 13.73 14.54 14.68 16.13 19.81 15.34 21.16 16.65 17.14 14.58
#  [25] 18.61 15.30 17.57 18.63 11.84 17.02 19.27 16.13 16.74 14.25 14.99 13.48
#  [37] 13.44 10.95 19.07 13.28 13.17 18.65 13.17 18.22 15.10 19.21 14.71 14.25
#  [49] 12.68 14.78 18.94 17.20 13.80 16.07 18.05 20.18 25.22 19.10 18.46 14.48
#  [61] 19.02 15.37 15.06 20.26 14.42 13.61 13.11 22.27 14.87 15.78 17.95 18.66
#  [73] 24.25 13.61 19.00 19.79 15.46 16.16 18.45 12.77 14.95 16.11 11.80 17.68
#  [85] 19.19 19.59 23.27 16.78 17.47 13.43 15.46 16.46 27.22 21.09 15.70 15.28
#  [97] 18.31 14.22 12.34 14.86 13.77 18.08 19.18 14.45 17.54 23.29 13.81 15.12
# [109] 17.01 20.58 28.11 17.42 14.19 13.86 19.80 19.53 15.75 12.83 17.05 20.51
# [121] 23.21 20.48 17.46 19.40 20.94 19.73 17.30 19.45 13.96 19.55 15.32 15.66
# [133] 15.53 20.31 17.35 17.29 15.61 17.19 20.73 21.75 17.93 18.81 19.16 19.40
# ...

# %%
benign_data <- subset(df2, diagnosis == 'B')$radius_mean
benign_data
# Out:
#   [1] 13.540 13.080  9.504 13.030  8.196 12.050 13.490 11.760 13.640 11.940
#  [11] 11.520 13.050  8.618 10.170  8.598  9.173  9.465 11.310  9.029 12.780
#  [21]  8.888 12.310 13.530 12.860 11.450 13.340 12.000 12.360 14.640 14.620
#  [31] 13.270 13.450 12.180  9.787 11.600  6.981 12.180  9.876 10.490 11.640
#  [41] 12.360 11.340  9.777 12.630 14.260 10.510  8.726 11.930  8.950 11.410
#  [51] 14.500 13.370 13.850 15.100 12.190 15.710 11.710 11.430 11.280  9.738
#  [61] 11.430 12.900 10.750 11.900 14.950 14.440 13.740 13.000  8.219  9.731
#  [71] 11.150 13.150 12.250 16.840 12.060 10.900 11.750 12.340 14.970 10.800
#  [81] 14.970 12.320 11.080 10.660  8.671  9.904 13.010 12.810 11.410 10.080
#  [91] 11.710 11.810 12.300 12.770  9.720 12.910 12.230 12.470  9.876 13.110
# [101] 15.270 11.840 11.890 10.200 13.650 13.560 10.180 13.270 14.340 10.440
# [111] 15.000 12.620 11.320 11.220  9.567 14.030 14.220 13.640 12.420 11.300
# ...

# %%
t_test_result <- t.test(malignant_data, benign_data, var.equal = FALSE)
t_test_result
# Out:
# 	Welch Two Sample t-test
#
# data:  malignant_data and benign_data
# t = 22.209, df = 289.71, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  4.845165 5.787448
# sample estimates:
# mean of x mean of y
#  17.46283  12.14652

# %% [markdown]
# # ANOVA

# %%
df3 = read.csv('readmission.csv')
df3
# Out:
#       Facility.Name                       Facility.ID State
# 1     SOUTHEAST HEALTH MEDICAL CENTER     10001       AL
# 2     SOUTHEAST HEALTH MEDICAL CENTER     10001       AL
# 3     SOUTHEAST HEALTH MEDICAL CENTER     10001       AL
# 4     SOUTHEAST HEALTH MEDICAL CENTER     10001       AL
# 5     SOUTHEAST HEALTH MEDICAL CENTER     10001       AL
# 6     SOUTHEAST HEALTH MEDICAL CENTER     10001       AL
# 7     MARSHALL MEDICAL CENTERS            10005       AL
# 8     MARSHALL MEDICAL CENTERS            10005       AL
# 9     MARSHALL MEDICAL CENTERS            10005       AL
# 10    MARSHALL MEDICAL CENTERS            10005       AL
# 11    MARSHALL MEDICAL CENTERS            10005       AL
# 12    MARSHALL MEDICAL CENTERS            10005       AL
# 13    NORTH ALABAMA MEDICAL CENTER        10006       AL
# 14    NORTH ALABAMA MEDICAL CENTER        10006       AL
# 15    NORTH ALABAMA MEDICAL CENTER        10006       AL
# ...

# %%
colnames(df3)[5] = "number_of_discharges"
colnames(df3)[3] = "state"

# %%
# Remove rows with missing values
df3[df3 == "N/A"] <- NA

# %%
print(df3)
# Out:
#                                                                 Facility.Name
# 1                                             SOUTHEAST HEALTH MEDICAL CENTER
# 2                                             SOUTHEAST HEALTH MEDICAL CENTER
# 3                                             SOUTHEAST HEALTH MEDICAL CENTER
# 4                                             SOUTHEAST HEALTH MEDICAL CENTER
# 5                                             SOUTHEAST HEALTH MEDICAL CENTER
# 6                                             SOUTHEAST HEALTH MEDICAL CENTER
# 7                                                    MARSHALL MEDICAL CENTERS
# 8                                                    MARSHALL MEDICAL CENTERS
# 9                                                    MARSHALL MEDICAL CENTERS
# 10                                                   MARSHALL MEDICAL CENTERS
# 11                                                   MARSHALL MEDICAL CENTERS
# ...

# %%
model <- aov(number_of_discharges ~ state, data=df3)
summary(model)
# Out:
#               Df    Sum Sq Mean Sq F value Pr(>F)
# state         50  20472758  409455   6.279 <2e-16 ***
# Residuals   9288 605695973   65213
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# 9651 observations deleted due to missingness

# %% [markdown]
# # Regression Analysis

# %%
library(ggplot2)

# %%
df4 <- read.csv("insurance.csv")
df4
# Out:
#      age sex    bmi    children smoker region    charges
# 1    19  female 27.900 0        yes    southwest 16884.924
# 2    18  male   33.770 1        no     southeast  1725.552
# 3    28  male   33.000 3        no     southeast  4449.462
# 4    33  male   22.705 0        no     northwest 21984.471
# 5    32  male   28.880 0        no     northwest  3866.855
# 6    31  female 25.740 0        no     southeast  3756.622
# 7    46  female 33.440 1        no     southeast  8240.590
# 8    37  female 27.740 3        no     northwest  7281.506
# 9    37  male   29.830 2        no     northeast  6406.411
# 10   60  female 25.840 0        no     northwest 28923.137
# 11   25  male   26.220 0        no     northeast  2721.321
# 12   62  female 26.290 0        yes    southeast 27808.725
# 13   23  male   34.400 0        no     southwest  1826.843
# 14   56  female 39.820 0        no     southeast 11090.718
# 15   27  male   42.130 0        yes    southeast 39611.758
# ...

# %%
independent_variable = df4[['age']]
dependent_variable = df4[['charges']]

# %%
model <- lm(dependent_variable ~ independent_variable, data = data)

# %%
summary(model)
# Out:
# Call:
# lm(formula = dependent_variable ~ independent_variable, data = data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#  -8059  -6671  -5939   5440  47829
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)            3165.9      937.1   3.378 0.000751 ***
# independent_variable    257.7       22.5  11.453  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 11560 on 1336 degrees of freedom
# Multiple R-squared:  0.08941,	Adjusted R-squared:  0.08872
# F-statistic: 131.2 on 1 and 1336 DF,  p-value: < 2.2e-16
